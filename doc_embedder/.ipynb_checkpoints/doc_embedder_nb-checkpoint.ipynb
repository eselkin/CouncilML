# %% [markdown]
# ## Environment Variables

# %%
FASTTEXT_BIN_FILENAME = "../../data/fasttext_wiki.simple/wiki.simple" # No extension
AGENDAS_FILE = "../agendas_2017"

# %% [markdown]
# ## Load FastText word vectors

# %%
from gensim.models.fasttext import FastText 
ft_vectors = FastText.load_fasttext_format(FASTTEXT_BIN_FILENAME)
# Out:
# c:\users\yihua\appdata\local\programs\python\python36\lib\site-packages\gensim\utils.py:1167: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## Compute tag vectors

# %%
tag_list = [
  "Community",
  "Learning",
  "Health",
  "Economic opportunity",
  "Responsive government",
  "Environment",
  "Sustainability",
  "Public Safety",
  "Parks & Recreation",
  "Free Speech",
  "Housing",
  "Mobility",
  "Pets",
  "Zoning",
  "Infrastructure",
  "Sanitation",
]

import numpy as np
import pandas as pd
from sklearn.preprocessing import normalize

def normalize_1d(arr):
  return normalize(arr.reshape((-1, 1)), axis=0).reshape(-1)

norm_tag_vectors_df = pd.DataFrame([[normalize_1d(ft_vectors[tag])] for tag in tag_list], index=tag_list)
norm_tag_vectors_df.head()
# Out:
# c:\users\yihua\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:27: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#                                                                        0
# Community              [0.10735343, 0.014057035, 0.056707624, -0.0995...
# Learning               [-0.013729809, 0.018801544, 0.064229235, -0.19...
# Health                 [0.08409269, -0.026365058, 0.08656505, -0.0426...
# Economic opportunity   [0.11906816, 0.026669413, 0.0435833, -0.045904...
# Responsive government  [0.03052185, -0.07070705, 0.111598186, -0.0647...

# %% [markdown]
# ## Plotting and document vector helpers

# %%
import matplotlib.pyplot as plt 
import nltk
import re
from sklearn.manifold import TSNE

nltk.download('stopwords')
STOP_WORDS = nltk.corpus.stopwords.words()

def tsne_scatter_plot(vectors, tags, figsize=(20, 10)):
  tsne = TSNE(n_components=2)
  vectors_tsne = tsne.fit_transform(vectors)
  vectors_tsne_x = vectors_tsne[:, 0]
  vectors_tsne_y = vectors_tsne[:, 1]
  
  plt.rcParams["figure.figsize"] = figsize
  plt.scatter(vectors_tsne_x, vectors_tsne_y)
  for i, tag in enumerate(tags):
    plt.annotate(tag, (vectors_tsne_x[i], vectors_tsne_y[i]))
  plt.show()
  
def clean_sentence(ft_vectors, sentence):
  # Returns a list of tokens after lowercasing and removing punctuation + stop words.
  regex = re.compile('([^\s\w]|_)+')
  sentence = regex.sub('', sentence).lower().split()
  return [word for word in sentence if (word not in STOP_WORDS and word in ft_vectors.wv.vocab)]

def doc_vector_simple(word_vectors):
  return np.mean(word_vectors, axis=0)

# def doc_vector_sif(word_vectors):
#   return np.mean(word_vectors, axis=0)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yihua\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ##  Plot normalized tag vectors

# %%
tsne_scatter_plot(norm_tag_vectors_df[0].tolist(), tag_list)

# %% [markdown]
# ## Load agendas

# %%
import json

agenda_items = []
with open(AGENDAS_FILE) as agendas_file:  
  data = json.load(agendas_file)
  for k in data:
    for item_list in data[k]:
      agenda_items.extend(item_list)

# %% [markdown]
# ## Load agendas into DataFrames

# %%
agenda_dfs = pd.DataFrame(index=[item["Title"] for item in agenda_items], columns=['title_doc_vector'])
for i, title in enumerate(agenda_dfs.index):
  title_word_vectors = [normalize_1d(ft_vectors[word]) for word in clean_sentence(ft_vectors, title)]
  agenda_dfs.iloc[i] = [doc_vector_simple(title_word_vectors)]

for tag in tag_list:
  agenda_dfs["title_rv_" + tag] = (agenda_dfs["title_doc_vector"] * norm_tag_vectors_df.loc[tag][0]).apply(lambda x: x.sum())
  
agenda_dfs.head()
# Out:
# c:\users\yihua\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                                                      title_doc_vector  \
# Annual Reporting of Development Impact Fees         [0.030360704, 0.0046201823, 0.064442985, -0.08...
# Construction Contract for the Beach Lifeguard H...  [0.08036537, -0.005429083, 0.03268578, -0.0683...
# Santa Monica Tourism Marketing District Annual ...  [0.049768027, -0.003398062, 0.047734167, -0.04...
# Funding for Affordable Housing In Venice            [0.08354552, 0.028868727, 0.065896735, -0.0738...
# Contract Approval for Design Services for Olymp...  [0.033686385, -0.014413595, 0.011930749, -0.05...
#
#                                                     title_rv_Community  \
# Annual Reporting of Development Impact Fees                   0.196370
# Construction Contract for the Beach Lifeguard H...            0.223070
# Santa Monica Tourism Marketing District Annual ...            0.165348
# Funding for Affordable Housing In Venice                      0.254582
# Contract Approval for Design Services for Olymp...            0.163404
#
#                                                     title_rv_Learning  \
# Annual Reporting of Development Impact Fees                  0.268102
# Construction Contract for the Beach Lifeguard H...           0.203473
# Santa Monica Tourism Marketing District Annual ...           0.208088
# Funding for Affordable Housing In Venice                     0.267710
# Contract Approval for Design Services for Olymp...           0.207847
#
#                                                     title_rv_Health  \
# Annual Reporting of Development Impact Fees                0.266914
# Construction Contract for the Beach Lifeguard H...         0.229153
# Santa Monica Tourism Marketing District Annual ...         0.213852
# Funding for Affordable Housing In Venice                   0.353900
# Contract Approval for Design Services for Olymp...         0.204558
#
#                                                     title_rv_Economic opportunity  \
# Annual Reporting of Development Impact Fees                              0.361601
# Construction Contract for the Beach Lifeguard H...                       0.298696
# Santa Monica Tourism Marketing District Annual ...                       0.301172
# Funding for Affordable Housing In Venice                                 0.378399
# Contract Approval for Design Services for Olymp...                       0.262636
#
#                                                     title_rv_Responsive government  \
# Annual Reporting of Development Impact Fees                               0.332440
# Construction Contract for the Beach Lifeguard H...                        0.314529
# Santa Monica Tourism Marketing District Annual ...                        0.283218
# Funding for Affordable Housing In Venice                                  0.383121
# Contract Approval for Design Services for Olymp...                        0.277116
#
#                                                     title_rv_Environment  \
# Annual Reporting of Development Impact Fees                     0.278004
# Construction Contract for the Beach Lifeguard H...              0.243299
# Santa Monica Tourism Marketing District Annual ...              0.205175
# Funding for Affordable Housing In Venice                        0.309726
# Contract Approval for Design Services for Olymp...              0.202194
#
#                                                     title_rv_Sustainability  \
# Annual Reporting of Development Impact Fees                        0.315136
# Construction Contract for the Beach Lifeguard H...                 0.250725
# Santa Monica Tourism Marketing District Annual ...                 0.260009
# Funding for Affordable Housing In Venice                           0.358890
# Contract Approval for Design Services for Olymp...                 0.253370
#
#                                                     title_rv_Public Safety  \
# Annual Reporting of Development Impact Fees                       0.270291
# Construction Contract for the Beach Lifeguard H...                0.264832
# Santa Monica Tourism Marketing District Annual ...                0.233121
# Funding for Affordable Housing In Venice                          0.310272
# Contract Approval for Design Services for Olymp...                0.285092
#
#                                                     title_rv_Parks & Recreation  \
# Annual Reporting of Development Impact Fees                            0.287030
# Construction Contract for the Beach Lifeguard H...                     0.307834
# Santa Monica Tourism Marketing District Annual ...                     0.255709
# Funding for Affordable Housing In Venice                               0.305401
# Contract Approval for Design Services for Olymp...                     0.303107
#
#                                                     title_rv_Free Speech  \
# Annual Reporting of Development Impact Fees                     0.203348
# Construction Contract for the Beach Lifeguard H...              0.175687
# Santa Monica Tourism Marketing District Annual ...              0.202180
# Funding for Affordable Housing In Venice                        0.172107
# Contract Approval for Design Services for Olymp...              0.194327
#
#                                                     title_rv_Housing  \
# Annual Reporting of Development Impact Fees                 0.258945
# Construction Contract for the Beach Lifeguard H...          0.290126
# Santa Monica Tourism Marketing District Annual ...          0.218841
# Funding for Affordable Housing In Venice                    0.443481
# Contract Approval for Design Services for Olymp...          0.279991
#
#                                                     title_rv_Mobility  \
# Annual Reporting of Development Impact Fees                  0.273068
# Construction Contract for the Beach Lifeguard H...           0.221224
# Santa Monica Tourism Marketing District Annual ...           0.168924
# Funding for Affordable Housing In Venice                     0.324179
# Contract Approval for Design Services for Olymp...           0.268414
#
#                                                     title_rv_Pets  \
# Annual Reporting of Development Impact Fees              0.173236
# Construction Contract for the Beach Lifeguard H...       0.147784
# Santa Monica Tourism Marketing District Annual ...       0.107520
# Funding for Affordable Housing In Venice                 0.212003
# Contract Approval for Design Services for Olymp...       0.192283
#
#                                                     title_rv_Zoning  \
# Annual Reporting of Development Impact Fees                0.226740
# Construction Contract for the Beach Lifeguard H...         0.185694
# Santa Monica Tourism Marketing District Annual ...         0.136566
# Funding for Affordable Housing In Venice                   0.193097
# Contract Approval for Design Services for Olymp...         0.183417
#
#                                                     title_rv_Infrastructure  \
# Annual Reporting of Development Impact Fees                        0.308177
# Construction Contract for the Beach Lifeguard H...                 0.329590
# Santa Monica Tourism Marketing District Annual ...                 0.231398
# Funding for Affordable Housing In Venice                           0.397745
# Contract Approval for Design Services for Olymp...                 0.287764
#
#                                                     title_rv_Sanitation
# Annual Reporting of Development Impact Fees                    0.293340
# Construction Contract for the Beach Lifeguard H...             0.279489
# Santa Monica Tourism Marketing District Annual ...             0.227913
# Funding for Affordable Housing In Venice                       0.318619
# Contract Approval for Design Services for Olymp...             0.265262

# %% [markdown]
# ## Plot title document vectors

# %%
tsne_scatter_plot(agenda_dfs["title_doc_vector"].tolist(), [title[:35] + "..." for title in agenda_dfs.index])

# %% [markdown]
# ## Plot projections on tag vectors

# %%
def plot_relevancy_vector(vector, title):
  y_pos = np.arange(len(tag_list))
  plt.bar(y_pos, vector, align='center', alpha=0.5)
  plt.xticks(y_pos, tag_list, rotation=45)
  plt.title(title)
  plt.show()
  
plot_relevancy_vector(agenda_dfs.iloc[0,1:], agenda_dfs.index[0])

# %% [markdown]
# ## List most relevant documents for each tag

# %%
agenda_dfs.sort_values(by="title_rv_Sanitation", ascending=False).head(10)
# Out:
#                                                                                      title_doc_vector  \
# BBB Facilities HVAC Maintenance and Repair          [0.056498386, 0.004387873, 0.0439135, -0.11135...
# Annual Homelessness Report                          [0.045814533, -0.0018323228, 0.07521527, -0.06...
# Strategy for Long-Term Economic Sustainability      [0.111691654, -0.032399997, 0.07884707, -0.114...
# Strategy for Long-Term Economic Sustainability      [0.111691654, -0.032399997, 0.07884707, -0.114...
# Clinical Services Contract to Support Affordabl...  [0.078975625, 0.0181596, 0.016515138, -0.06632...
# Modification of Software Maintenance and Suppor...  [0.06252259, -0.033254165, 0.029699858, -0.093...
# Software Maintenance and Support Services Contr...  [0.07678664, -0.012364803, 0.019901702, -0.069...
# Proclamation Declaring May 2017 as Mental Healt...  [0.020494929, -0.01756509, 0.021806175, -0.024...
# Fourth Modification to Agreement 9210 (CCS) for...  [0.052498695, 0.009768067, 0.036755808, -0.054...
# Modification to Gafcon Contract for Citywide Pr...  [0.02641511, -0.023658762, 0.026105793, -0.047...
#
#                                                     title_rv_Community  \
# BBB Facilities HVAC Maintenance and Repair                    0.193055
# Annual Homelessness Report                                    0.201121
# Strategy for Long-Term Economic Sustainability                0.241412
# Strategy for Long-Term Economic Sustainability                0.241412
# Clinical Services Contract to Support Affordabl...            0.204480
# Modification of Software Maintenance and Suppor...            0.193068
# Software Maintenance and Support Services Contr...            0.193819
# Proclamation Declaring May 2017 as Mental Healt...            0.206220
# Fourth Modification to Agreement 9210 (CCS) for...            0.156154
# Modification to Gafcon Contract for Citywide Pr...            0.172975
#
#                                                     title_rv_Learning  \
# BBB Facilities HVAC Maintenance and Repair                   0.228381
# Annual Homelessness Report                                   0.258407
# Strategy for Long-Term Economic Sustainability               0.285229
# Strategy for Long-Term Economic Sustainability               0.285229
# Clinical Services Contract to Support Affordabl...           0.247700
# Modification of Software Maintenance and Suppor...           0.220518
# Software Maintenance and Support Services Contr...           0.234512
# Proclamation Declaring May 2017 as Mental Healt...           0.292818
# Fourth Modification to Agreement 9210 (CCS) for...           0.260406
# Modification to Gafcon Contract for Citywide Pr...           0.247335
#
#                                                     title_rv_Health  \
# BBB Facilities HVAC Maintenance and Repair                 0.241728
# Annual Homelessness Report                                 0.290611
# Strategy for Long-Term Economic Sustainability             0.410534
# Strategy for Long-Term Economic Sustainability             0.410534
# Clinical Services Contract to Support Affordabl...         0.312629
# Modification of Software Maintenance and Suppor...         0.258155
# Software Maintenance and Support Services Contr...         0.281402
# Proclamation Declaring May 2017 as Mental Healt...         0.355631
# Fourth Modification to Agreement 9210 (CCS) for...         0.262875
# Modification to Gafcon Contract for Citywide Pr...         0.248096
#
#                                                     title_rv_Economic opportunity  \
# BBB Facilities HVAC Maintenance and Repair                               0.275850
# Annual Homelessness Report                                               0.338605
# Strategy for Long-Term Economic Sustainability                           0.485848
# Strategy for Long-Term Economic Sustainability                           0.485848
# Clinical Services Contract to Support Affordabl...                       0.346983
# Modification of Software Maintenance and Suppor...                       0.286744
# Software Maintenance and Support Services Contr...                       0.303986
# Proclamation Declaring May 2017 as Mental Healt...                       0.302754
# Fourth Modification to Agreement 9210 (CCS) for...                       0.288091
# Modification to Gafcon Contract for Citywide Pr...                       0.335096
#
#                                                     title_rv_Responsive government  \
# BBB Facilities HVAC Maintenance and Repair                                0.323911
# Annual Homelessness Report                                                0.351517
# Strategy for Long-Term Economic Sustainability                            0.400573
# Strategy for Long-Term Economic Sustainability                            0.400573
# Clinical Services Contract to Support Affordabl...                        0.359753
# Modification of Software Maintenance and Suppor...                        0.320556
# Software Maintenance and Support Services Contr...                        0.360037
# Proclamation Declaring May 2017 as Mental Healt...                        0.327524
# Fourth Modification to Agreement 9210 (CCS) for...                        0.314888
# Modification to Gafcon Contract for Citywide Pr...                        0.352104
#
#                                                     title_rv_Environment  \
# BBB Facilities HVAC Maintenance and Repair                      0.256763
# Annual Homelessness Report                                      0.274247
# Strategy for Long-Term Economic Sustainability                  0.427577
# Strategy for Long-Term Economic Sustainability                  0.427577
# Clinical Services Contract to Support Affordabl...              0.268686
# Modification of Software Maintenance and Suppor...              0.308897
# Software Maintenance and Support Services Contr...              0.269234
# Proclamation Declaring May 2017 as Mental Healt...              0.255751
# Fourth Modification to Agreement 9210 (CCS) for...              0.235479
# Modification to Gafcon Contract for Citywide Pr...              0.271660
#
#                                                     title_rv_Sustainability  \
# BBB Facilities HVAC Maintenance and Repair                         0.279660
# Annual Homelessness Report                                         0.387860
# Strategy for Long-Term Economic Sustainability                     0.589508
# Strategy for Long-Term Economic Sustainability                     0.589508
# Clinical Services Contract to Support Affordabl...                 0.359515
# Modification of Software Maintenance and Suppor...                 0.343571
# Software Maintenance and Support Services Contr...                 0.329911
# Proclamation Declaring May 2017 as Mental Healt...                 0.330138
# Fourth Modification to Agreement 9210 (CCS) for...                 0.300392
# Modification to Gafcon Contract for Citywide Pr...                 0.317603
#
#                                                     title_rv_Public Safety  \
# BBB Facilities HVAC Maintenance and Repair                        0.291369
# Annual Homelessness Report                                        0.303442
# Strategy for Long-Term Economic Sustainability                    0.264233
# Strategy for Long-Term Economic Sustainability                    0.264233
# Clinical Services Contract to Support Affordabl...                0.292206
# Modification of Software Maintenance and Suppor...                0.288855
# Software Maintenance and Support Services Contr...                0.302661
# Proclamation Declaring May 2017 as Mental Healt...                0.347507
# Fourth Modification to Agreement 9210 (CCS) for...                0.306947
# Modification to Gafcon Contract for Citywide Pr...                0.300216
#
#                                                     title_rv_Parks & Recreation  \
# BBB Facilities HVAC Maintenance and Repair                             0.325353
# Annual Homelessness Report                                             0.289826
# Strategy for Long-Term Economic Sustainability                         0.310857
# Strategy for Long-Term Economic Sustainability                         0.310857
# Clinical Services Contract to Support Affordabl...                     0.281893
# Modification of Software Maintenance and Suppor...                     0.309248
# Software Maintenance and Support Services Contr...                     0.301014
# Proclamation Declaring May 2017 as Mental Healt...                     0.272282
# Fourth Modification to Agreement 9210 (CCS) for...                     0.292924
# Modification to Gafcon Contract for Citywide Pr...                     0.286273
#
#                                                     title_rv_Free Speech  \
# BBB Facilities HVAC Maintenance and Repair                      0.150892
# Annual Homelessness Report                                      0.272392
# Strategy for Long-Term Economic Sustainability                  0.265692
# Strategy for Long-Term Economic Sustainability                  0.265692
# Clinical Services Contract to Support Affordabl...              0.205491
# Modification of Software Maintenance and Suppor...              0.194655
# Software Maintenance and Support Services Contr...              0.203593
# Proclamation Declaring May 2017 as Mental Healt...              0.262785
# Fourth Modification to Agreement 9210 (CCS) for...              0.224524
# Modification to Gafcon Contract for Citywide Pr...              0.211978
#
#                                                     title_rv_Housing  \
# BBB Facilities HVAC Maintenance and Repair                  0.321490
# Annual Homelessness Report                                  0.259826
# Strategy for Long-Term Economic Sustainability              0.322466
# Strategy for Long-Term Economic Sustainability              0.322466
# Clinical Services Contract to Support Affordabl...          0.398873
# Modification of Software Maintenance and Suppor...          0.268000
# Software Maintenance and Support Services Contr...          0.354906
# Proclamation Declaring May 2017 as Mental Healt...          0.274443
# Fourth Modification to Agreement 9210 (CCS) for...          0.293290
# Modification to Gafcon Contract for Citywide Pr...          0.296188
#
#                                                     title_rv_Mobility  \
# BBB Facilities HVAC Maintenance and Repair                   0.301808
# Annual Homelessness Report                                   0.276204
# Strategy for Long-Term Economic Sustainability               0.392191
# Strategy for Long-Term Economic Sustainability               0.392191
# Clinical Services Contract to Support Affordabl...           0.333219
# Modification of Software Maintenance and Suppor...           0.305774
# Software Maintenance and Support Services Contr...           0.329020
# Proclamation Declaring May 2017 as Mental Healt...           0.303366
# Fourth Modification to Agreement 9210 (CCS) for...           0.297382
# Modification to Gafcon Contract for Citywide Pr...           0.314854
#
#                                                     title_rv_Pets  \
# BBB Facilities HVAC Maintenance and Repair               0.241490
# Annual Homelessness Report                               0.138633
# Strategy for Long-Term Economic Sustainability           0.147938
# Strategy for Long-Term Economic Sustainability           0.147938
# Clinical Services Contract to Support Affordabl...       0.212004
# Modification of Software Maintenance and Suppor...       0.184949
# Software Maintenance and Support Services Contr...       0.201684
# Proclamation Declaring May 2017 as Mental Healt...       0.166277
# Fourth Modification to Agreement 9210 (CCS) for...       0.207477
# Modification to Gafcon Contract for Citywide Pr...       0.171540
#
#                                                     title_rv_Zoning  \
# BBB Facilities HVAC Maintenance and Repair                 0.224957
# Annual Homelessness Report                                 0.199002
# Strategy for Long-Term Economic Sustainability             0.221008
# Strategy for Long-Term Economic Sustainability             0.221008
# Clinical Services Contract to Support Affordabl...         0.183766
# Modification of Software Maintenance and Suppor...         0.229408
# Software Maintenance and Support Services Contr...         0.199254
# Proclamation Declaring May 2017 as Mental Healt...         0.263432
# Fourth Modification to Agreement 9210 (CCS) for...         0.226655
# Modification to Gafcon Contract for Citywide Pr...         0.235513
#
#                                                     title_rv_Infrastructure  \
# BBB Facilities HVAC Maintenance and Repair                         0.384421
# Annual Homelessness Report                                         0.270076
# Strategy for Long-Term Economic Sustainability                     0.422211
# Strategy for Long-Term Economic Sustainability                     0.422211
# Clinical Services Contract to Support Affordabl...                 0.362858
# Modification of Software Maintenance and Suppor...                 0.357629
# Software Maintenance and Support Services Contr...                 0.374626
# Proclamation Declaring May 2017 as Mental Healt...                 0.235941
# Fourth Modification to Agreement 9210 (CCS) for...                 0.303155
# Modification to Gafcon Contract for Citywide Pr...                 0.310764
#
#                                                     title_rv_Sanitation
# BBB Facilities HVAC Maintenance and Repair                     0.365429
# Annual Homelessness Report                                     0.356843
# Strategy for Long-Term Economic Sustainability                 0.352466
# Strategy for Long-Term Economic Sustainability                 0.352466
# Clinical Services Contract to Support Affordabl...             0.351664
# Modification of Software Maintenance and Suppor...             0.349483
# Software Maintenance and Support Services Contr...             0.349342
# Proclamation Declaring May 2017 as Mental Healt...             0.346671
# Fourth Modification to Agreement 9210 (CCS) for...             0.344417
# Modification to Gafcon Contract for Citywide Pr...             0.339922

# %% [markdown]
# ## Plot per-tag variance

# %%
def plot_avg_variance(vector):
  y_pos = np.arange(len(tag_list))
  plt.bar(y_pos, vector, align='center', alpha=0.5)
  plt.xticks(y_pos, tag_list, rotation=45)
  plt.show()
  
plot_avg_variance(agenda_dfs.iloc[:, 1:].var())
